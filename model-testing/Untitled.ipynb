# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Draw boxes for processes
box_properties = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.2, 0.8, 'Extract Data\nFrom GRIB Files', transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=box_properties)
ax.text(0.2, 0.5, 'Split Data\nTrain-Test Split', transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=box_properties)
ax.text(0.2, 0.2, 'Train Model\nLinear Regression', transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=box_properties)
ax.text(0.8, 0.5, 'Make Predictions\n&\nGenerate Outputs', transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=box_properties)

# Draw arrows between boxes
plt.arrow(0.3, 0.72, 0, -0.15, width=0.01, head_width=0.05, head_length=0.1, fc='k', ec='k')
plt.arrow(0.3, 0.42, 0, -0.15, width=0.01, head_width=0.05, head_length=0.1, fc='k', ec='k')
plt.arrow(0.3, 0.12, 0.45, 0.25, width=0.01, head_width=0.05, head_length=0.1, fc='k', ec='k')

plt.axis('off')
plt.show()
